# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
data=pd.read_csv('hotel_bookings.csv')
df=pd.DataFrame(data)
df.head(10)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
# 5  Resort Hotel            0         14               2015               July
# 6  Resort Hotel            0          0               2015               July
# 7  Resort Hotel            0          9               2015               July
# 8  Resort Hotel            1         85               2015               July
# 9  Resort Hotel            1         75               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df.corr()
# Out:
#                                 is_canceled  lead_time  arrival_date_year  \
# is_canceled                        1.000000   0.293123           0.016660
# lead_time                          0.293123   1.000000           0.040142
# arrival_date_year                  0.016660   0.040142           1.000000
# arrival_date_week_number           0.008148   0.126871          -0.540561
# arrival_date_day_of_month         -0.006130   0.002268          -0.000221
# stays_in_weekend_nights           -0.001791   0.085671           0.021497
# stays_in_week_nights               0.024765   0.165799           0.030883
# adults                             0.060017   0.119519           0.029635
# children                           0.005048  -0.037622           0.054624
# babies                            -0.032491  -0.020915          -0.013192
# is_repeated_guest                 -0.084793  -0.124410           0.010341
# previous_cancellations             0.110133   0.086042          -0.119822
# ...

# %%
df.drop('company', axis=1, inplace=True)

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 0                        0                     0       2  ...
# ...

# %%
df['agent'].mean()
# Out:
# 86.69338185346919

# %%
df.fillna({
    'agent':87.0,
    'country':'no data',
    'children': 0
},inplace=True)

# %%
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# days_in_waiting_list              0
# customer_type                     0
# ...

# %%
sns.barplot(x='arrival_date_year',y='is_canceled', data=df)
# Out:
# <AxesSubplot:xlabel='arrival_date_year', ylabel='is_canceled'>

# %%
df.hist(figsize=(22,13))
plt.show()

# %%
data1=df.pivot_table(index='arrival_date_month',columns='arrival_date_year', values='is_canceled')
sns.heatmap(data1,cmap='Reds')
# Out:
# <AxesSubplot:xlabel='arrival_date_year', ylabel='arrival_date_month'>

# %%
hotel=df.copy()
hotel["hotel"].value_counts()
# Out:
# City Hotel      79330
# Resort Hotel    40060
# Name: hotel, dtype: int64

# %%
plt.figure(figsize=(20,10))
sns.countplot(x="is_canceled", hue="hotel",data=hotel)
plt.show()

# %%
hotel['customer_type'].value_counts()/hotel['customer_type'].shape[0]*100
# Out:
# Transient          75.059050
# Transient-Party    21.043638
# Contract            3.414021
# Group               0.483290
# Name: customer_type, dtype: float64

# %%
hotel['is_canceled'].value_counts()
# Out:
# 0    75166
# 1    44224
# Name: is_canceled, dtype: int64

# %%
hotel['is_repeated_guest'].value_counts()
# Out:
# 0    115580
# 1      3810
# Name: is_repeated_guest, dtype: int64

# %%
sns.barplot(x='hotel', y='days_in_waiting_list', data=hotel)
# Out:
# <AxesSubplot:xlabel='hotel', ylabel='days_in_waiting_list'>

# %%
data2=df.pivot_table(index='arrival_date_month',columns='hotel', values='days_in_waiting_list')
sns.heatmap(data2,cmap='Reds')
# Out:
# <AxesSubplot:xlabel='hotel', ylabel='arrival_date_month'>

# %%
data3=df.pivot_table(index='arrival_date_month',columns='arrival_date_year', values='days_in_waiting_list')
sns.heatmap(data3,cmap='Blues')
# Out:
# <AxesSubplot:xlabel='arrival_date_year', ylabel='arrival_date_month'>

# %%
sns.barplot(x='booking_changes', y="market_segment", data=hotel,hue='hotel')
# Out:
# <AxesSubplot:xlabel='booking_changes', ylabel='market_segment'>

# %%
hotel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 31 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119390 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
hotel['Total_guests'] = hotel['adults']+hotel['children']+hotel['babies']
hotel.head(10)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
# 5  Resort Hotel            0         14               2015               July
# 6  Resort Hotel            0          0               2015               July
# 7  Resort Hotel            0          9               2015               July
# 8  Resort Hotel            1         85               2015               July
# 9  Resort Hotel            1         75               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# ...

# %%
data4=hotel.pivot_table(index='arrival_date_month',columns='arrival_date_year', values='Total_guests')
sns.heatmap(data4,cmap='Blues')
# Out:
# <AxesSubplot:xlabel='arrival_date_year', ylabel='arrival_date_month'>

# %%
hotel['deposit_type'].value_counts()
# Out:
# No Deposit    104641
# Non Refund     14587
# Refundable       162
# Name: deposit_type, dtype: int64

# %%
sns.scatterplot(x='customer_type', y='Total_guests', data=hotel,hue='hotel')
# Out:
# <AxesSubplot:xlabel='customer_type', ylabel='Total_guests'>

# %%
h = sns.FacetGrid(hotel , col="customer_type")
h.map(sns.histplot, "meal")

# %%
sns.barplot(x='stays_in_weekend_nights', y='customer_type', data=hotel)
# Out:
# <AxesSubplot:xlabel='stays_in_weekend_nights', ylabel='customer_type'>

# %%
x=hotel['stays_in_weekend_nights']
y=hotel['customer_type']
plt.scatter(x,y)

# %%
h = sns.FacetGrid(hotel , col="country")
h.map(sns.histplot, "market_segment")

# %%
hotel['country'].value_counts()
# Out:
# PRT    48590
# GBR    12129
# FRA    10415
# ESP     8568
# DEU     7287
#        ...
# BHS        1
# HND        1
# SMR        1
# MMR        1
# MRT        1
# Name: country, Length: 178, dtype: int64

# %%
hotel['distribution_channel'].value_counts()
# Out:
# TA/TO        97870
# Direct       14645
# Corporate     6677
# GDS            193
# Undefined        5
# Name: distribution_channel, dtype: int64
